# %%
import pandas as pd

# %%
bold_data_package = "/home/camilababo/Documents/DNAquaIMG/BOLD_Public.29-Nov-2024/BOLD_Public.29-Nov-2024.tsv"
# 25 Gb

# %%
df = pd.DataFrame()
for chunk in pd.read_csv(bold_data_package, sep="\t", on_bad_lines='skip', chunksize=1000):
    df = pd.concat([df, chunk], ignore_index=True)

# %%
df.head()
