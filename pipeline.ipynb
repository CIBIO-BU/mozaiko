# %%
# Files
data = "/home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/input_data/diat-barcode-taxa-harmonized.fasta"
primer_table = "/home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/input_data/diat-barcode-primers.tsv"
run_name = 'diat-barcode-harmonized-germ'

# %%
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord
import unicodedata
import re

def clean_fasta_headers(input_file, output_file):
    """
    Cleans FASTA headers by:
    1. Removing non-ASCII characters
    2. Replacing them with ASCII equivalents where possible
    3. Removing any remaining problematic characters

    Parameters:
    input_file (str): Path to input FASTA file
    output_file (str): Path to output FASTA file

    Returns:
    int: Number of processed sequences
    """
    def clean_header(header):
        normalized = unicodedata.normalize('NFKD', header)
        ascii_text = normalized.encode('ASCII', 'ignore').decode()
        clean_text = re.sub(r'[^\w\s|.-]', '', ascii_text)
        return clean_text

    cleaned_records = []
    problematic_headers = []

    with open(input_file, 'r', encoding='utf-8') as handle:
        for record in SeqIO.parse(handle, "fasta"):
            # Clean the header
            original_header = record.description
            cleaned_header = clean_header(original_header)

            if cleaned_header != original_header:
                problematic_headers.append((original_header, cleaned_header))

            new_record = SeqRecord(
                record.seq,
                id=clean_header(record.id),
                description=cleaned_header
            )
            cleaned_records.append(new_record)

    SeqIO.write(cleaned_records, output_file, "fasta")

    print(f"Processed {len(cleaned_records)} sequences")
    if problematic_headers:
        print("\nHeaders that were modified:")
        for orig, clean in problematic_headers:
            print(f"Original: {orig}")
            print(f"Cleaned : {clean}\n")

# %%
clean_fasta_headers(data, data)
# Out:
# Processed 9233 sequences

# %%
from src.in_silico_analysis.amplification import InSilicoAmplification

insil = InSilicoAmplification(data, run_name=run_name)
insil.run_in_silico_analysis(primer_table)
# Out:
# mozaiko INFO: Checking if cutadapt is installed...
# mozaiko INFO: cutadapt is installed.
# mozaiko INFO: Checking if CRABS is installed...
# mozaiko INFO: CRABS is installed.
# mozaiko INFO: To continue the analysis, a set of primers is needed. This information should be uploaded as a TSV table and it should contain the following fields: ['target_group', 'barcode_region', 'assay_name', 'fwd_seq', 'rev_seq']
# mozaiko INFO: All set. Running in-silico amplification...
# mozaiko INFO: Running cutadapt command as: cutadapt -g ATGCGTTGGAGAGARCGTTTC;min_overlap=21...CAGTTGTWGGTAAATTAGAAGGTGATC;min_overlap=27 --output ../data/output_data/diat-barcode-harmonized-consensus/amplicon/rbcL_646F_998R.fasta /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/DNAquaIMG/data/input_data/diat-barcode-taxa-harmonized.fasta --no-indels -e 3 --revcomp --quiet --minimum-length 0 --maximum-length 552 --discard-untrimmed --action retain
# mozaiko INFO: Running cutadapt command as: cutadapt -g ATGCGTTGGAGAGARCGTTTC;min_overlap=21...CAGTTGTWGGTAAATTAGAAGGTGATC;min_overlap=27 --output ../data/output_data/diat-barcode-harmonized-consensus/insert/rbcL_646F_998R.fasta /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/DNAquaIMG/data/input_data/diat-barcode-taxa-harmonized.fasta --no-indels -e 3 --revcomp --quiet --minimum-length 0 --maximum-length 552 --discard-untrimmed --action trim
# mozaiko INFO: Completed analysis for 646F_998R.
#    --------   1/8 processed   --------
# mozaiko INFO: Running cutadapt command as: cutadapt -g AGGTGAAGTAAAAGGTTCWTACTTAAA;min_overlap=27...CAGTWGTWGGTAAATTAGAAGG;min_overlap=22 --output ../data/output_data/diat-barcode-harmonized-consensus/amplicon/rbcL_708F1_R3-1.fasta /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/DNAquaIMG/data/input_data/diat-barcode-taxa-harmonized.fasta --no-indels -e 3 --revcomp --quiet --minimum-length 0 --maximum-length 551 --discard-untrimmed --action retain
# mozaiko INFO: Running cutadapt command as: cutadapt -g AGGTGAAGTAAAAGGTTCWTACTTAAA;min_overlap=27...CAGTWGTWGGTAAATTAGAAGG;min_overlap=22 --output ../data/output_data/diat-barcode-harmonized-consensus/insert/rbcL_708F1_R3-1.fasta /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/DNAquaIMG/data/input_data/diat-barcode-taxa-harmonized.fasta --no-indels -e 3 --revcomp --quiet --minimum-length 0 --maximum-length 551 --discard-untrimmed --action trim
# mozaiko INFO: Completed analysis for 708F1_R3-1.
#    --------   2/8 processed   --------
# mozaiko INFO: Running cutadapt command as: cutadapt -g AGGTGAAGTAAAAGGTTCWTACTTAAA;min_overlap=27...CTGTTGTWGGTAAATTAGAAGG;min_overlap=22 --output ../data/output_data/diat-barcode-harmonized-consensus/amplicon/rbcL_708F1_R3-2.fasta /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/DNAquaIMG/data/input_data/diat-barcode-taxa-harmonized.fasta --no-indels -e 3 --revcomp --quiet --minimum-length 0 --maximum-length 551 --discard-untrimmed --action retain
# mozaiko INFO: Running cutadapt command as: cutadapt -g AGGTGAAGTAAAAGGTTCWTACTTAAA;min_overlap=27...CTGTTGTWGGTAAATTAGAAGG;min_overlap=22 --output ../data/output_data/diat-barcode-harmonized-consensus/insert/rbcL_708F1_R3-2.fasta /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/DNAquaIMG/data/input_data/diat-barcode-taxa-harmonized.fasta --no-indels -e 3 --revcomp --quiet --minimum-length 0 --maximum-length 551 --discard-untrimmed --action trim
# mozaiko INFO: Completed analysis for 708F1_R3-2.
#    --------   3/8 processed   --------
# mozaiko INFO: Running cutadapt command as: cutadapt -g AGGTGAAGTTAAAGGTTCWTAYTTAAA;min_overlap=27...CAGTWGTWGGTAAATTAGAAGG;min_overlap=22 --output ../data/output_data/diat-barcode-harmonized-consensus/amplicon/rbcL_708F2_R3-1.fasta /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/DNAquaIMG/data/input_data/diat-barcode-taxa-harmonized.fasta --no-indels -e 3 --revcomp --quiet --minimum-length 0 --maximum-length 551 --discard-untrimmed --action retain
# mozaiko INFO: Running cutadapt command as: cutadapt -g AGGTGAAGTTAAAGGTTCWTAYTTAAA;min_overlap=27...CAGTWGTWGGTAAATTAGAAGG;min_overlap=22 --output ../data/output_data/diat-barcode-harmonized-consensus/insert/rbcL_708F2_R3-1.fasta /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/DNAquaIMG/data/input_data/diat-barcode-taxa-harmonized.fasta --no-indels -e 3 --revcomp --quiet --minimum-length 0 --maximum-length 551 --discard-untrimmed --action trim
# mozaiko INFO: Completed analysis for 708F2_R3-1.
#    --------   4/8 processed   --------
# mozaiko INFO: Running cutadapt command as: cutadapt -g AGGTGAAGTTAAAGGTTCWTAYTTAAA;min_overlap=27...CTGTTGTWGGTAAATTAGAAGG;min_overlap=22 --output ../data/output_data/diat-barcode-harmonized-consensus/amplicon/rbcL_708F2_R3-2.fasta /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/DNAquaIMG/data/input_data/diat-barcode-taxa-harmonized.fasta --no-indels -e 3 --revcomp --quiet --minimum-length 0 --maximum-length 551 --discard-untrimmed --action retain
# mozaiko INFO: Running cutadapt command as: cutadapt -g AGGTGAAGTTAAAGGTTCWTAYTTAAA;min_overlap=27...CTGTTGTWGGTAAATTAGAAGG;min_overlap=22 --output ../data/output_data/diat-barcode-harmonized-consensus/insert/rbcL_708F2_R3-2.fasta /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/DNAquaIMG/data/input_data/diat-barcode-taxa-harmonized.fasta --no-indels -e 3 --revcomp --quiet --minimum-length 0 --maximum-length 551 --discard-untrimmed --action trim
# mozaiko INFO: Completed analysis for 708F2_R3-2.
#    --------   5/8 processed   --------
# mozaiko INFO: Running cutadapt command as: cutadapt -g AGGTGAAACTAAAGGTTCWTACTTAAA;min_overlap=27...CAGTWGTWGGTAAATTAGAAGG;min_overlap=22 --output ../data/output_data/diat-barcode-harmonized-consensus/amplicon/rbcL_708F3_R3-1.fasta /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/DNAquaIMG/data/input_data/diat-barcode-taxa-harmonized.fasta --no-indels -e 3 --revcomp --quiet --minimum-length 0 --maximum-length 551 --discard-untrimmed --action retain
# mozaiko INFO: Running cutadapt command as: cutadapt -g AGGTGAAACTAAAGGTTCWTACTTAAA;min_overlap=27...CAGTWGTWGGTAAATTAGAAGG;min_overlap=22 --output ../data/output_data/diat-barcode-harmonized-consensus/insert/rbcL_708F3_R3-1.fasta /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/DNAquaIMG/data/input_data/diat-barcode-taxa-harmonized.fasta --no-indels -e 3 --revcomp --quiet --minimum-length 0 --maximum-length 551 --discard-untrimmed --action trim
# mozaiko INFO: Completed analysis for 708F3_R3-1.
#    --------   6/8 processed   --------
# mozaiko INFO: Running cutadapt command as: cutadapt -g AGGTGAAACTAAAGGTTCWTACTTAAA;min_overlap=27...CTGTTGTWGGTAAATTAGAAGG;min_overlap=22 --output ../data/output_data/diat-barcode-harmonized-consensus/amplicon/rbcL_708F3_R3-2.fasta /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/DNAquaIMG/data/input_data/diat-barcode-taxa-harmonized.fasta --no-indels -e 3 --revcomp --quiet --minimum-length 0 --maximum-length 551 --discard-untrimmed --action retain
# mozaiko INFO: Running cutadapt command as: cutadapt -g AGGTGAAACTAAAGGTTCWTACTTAAA;min_overlap=27...CTGTTGTWGGTAAATTAGAAGG;min_overlap=22 --output ../data/output_data/diat-barcode-harmonized-consensus/insert/rbcL_708F3_R3-2.fasta /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/DNAquaIMG/data/input_data/diat-barcode-taxa-harmonized.fasta --no-indels -e 3 --revcomp --quiet --minimum-length 0 --maximum-length 551 --discard-untrimmed --action trim
# mozaiko INFO: Completed analysis for 708F3_R3-2.
#    --------   7/8 processed   --------
# mozaiko INFO: Running cutadapt command as: cutadapt -g AGGTGAAGYWAAAGGTTCWTAYTTAAA;min_overlap=27...CWGTWGTWGGTAAATTAGAAGG;min_overlap=22 --output ../data/output_data/diat-barcode-harmonized-consensus/amplicon/rbcL_708F-DEG_R3-DEG.fasta /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/DNAquaIMG/data/input_data/diat-barcode-taxa-harmonized.fasta --no-indels -e 3 --revcomp --quiet --minimum-length 0 --maximum-length 551 --discard-untrimmed --action retain
# mozaiko INFO: Running cutadapt command as: cutadapt -g AGGTGAAGYWAAAGGTTCWTAYTTAAA;min_overlap=27...CWGTWGTWGGTAAATTAGAAGG;min_overlap=22 --output ../data/output_data/diat-barcode-harmonized-consensus/insert/rbcL_708F-DEG_R3-DEG.fasta /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/DNAquaIMG/data/input_data/diat-barcode-taxa-harmonized.fasta --no-indels -e 3 --revcomp --quiet --minimum-length 0 --maximum-length 551 --discard-untrimmed --action trim
# mozaiko INFO: Completed analysis for 708F-DEG_R3-DEG.
#    --------   8/8 processed   --------
# mozaiko INFO: Number of inserts that were amplified successfully...
#     For rbcL_708F1_R3-1, 4766 were retained.
#     For rbcL_708F2_R3-2, 4906 were retained.
#     For rbcL_708F-DEG_R3-DEG, 5034 were retained.
#     For rbcL_708F1_R3-2, 4762 were retained.
#     For rbcL_646F_998R, 4601 were retained.
#     For rbcL_708F2_R3-1, 4910 were retained.
#     For rbcL_708F3_R3-2, 4439 were retained.
#     For rbcL_708F3_R3-1, 4441 were retained.
# mozaiko INFO: Number of inserts with complete PBS that were not amplified...
#     For rbcL_708F1_R3-1: 316 sequences were retained.
#     For rbcL_708F2_R3-2: 316 sequences were retained.
#     For rbcL_708F-DEG_R3-DEG: 316 sequences were retained.
#     For rbcL_708F1_R3-2: 316 sequences were retained.
#     For rbcL_646F_998R: 186 sequences were retained.
#     For rbcL_708F2_R3-1: 316 sequences were retained.
#     For rbcL_708F3_R3-2: 316 sequences were retained.
#     For rbcL_708F3_R3-1: 316 sequences were retained.
#     For rbcL_708F1_R3-1: 292 sequences were retained.
#     For rbcL_708F2_R3-2: 152 sequences were retained.
#     For rbcL_708F-DEG_R3-DEG: 24 sequences were retained.
#     For rbcL_708F1_R3-2: 296 sequences were retained.
#     For rbcL_646F_998R: 18 sequences were retained.
#     For rbcL_708F2_R3-1: 148 sequences were retained.
#     For rbcL_708F3_R3-2: 619 sequences were retained.
#     For rbcL_708F3_R3-1: 617 sequences were retained.
# mozaiko INFO: Number of inserts with incomplete PBS...
#     For rbcL_708F1_R3-1: 608 sequences were retained.
#     For rbcL_708F2_R3-2: 468 sequences were retained.
#     For rbcL_708F-DEG_R3-DEG: 340 sequences were retained.
#     For rbcL_708F1_R3-2: 612 sequences were retained.
#     For rbcL_646F_998R: 204 sequences were retained.
#     For rbcL_708F2_R3-1: 464 sequences were retained.
#     For rbcL_708F3_R3-2: 935 sequences were retained.
#     For rbcL_708F3_R3-1: 933 sequences were retained.
# mozaiko INFO: In-silico amplification analysis completed.

# %%
from src.marker_scoring.metrics_system import *

otl_folder = '/home/camilababo/Documents/DNAquaIMG/countries-otls/harmonized-clean/dia'
output_folder = '/home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks'

for otl in os.listdir(otl_folder):
    otl_path = os.path.join(otl_folder, otl)
    country_name = otl.split('_')[0]
    output_path = os.path.join(output_folder, country_name + '_ranked_primers.tsv')
    print(" ---------------------")
    print(" ---- Processing OTL:", otl)
    mex = MetricsSystemExecutor(results_folder=output_folder, otl=otl_path, primer_table=primer_table)
    ranked_df = mex.rank_primers(save_intermediate_ranks=True, output_path=output_path)
# Out:
# /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Germany_ranked_primers.tsv
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# results_folder: /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks, insert_folder_path: None, amplicon_folder_path: None
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# mozaiko INFO: MultiBarcodeTools file created to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode/multibarcode_input.tsv
# mozaiko INFO: MultiBarcodePipeline completed. Output in /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode
# mozaiko INFO: Primer Ranking results saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Germany_ranked_primers.tsv.
# mozaiko INFO: Intermediate ranks saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Germany_ranked_primers_intermediate_ranks.tsv.
# /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Ireland_ranked_primers.tsv
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# results_folder: /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks, insert_folder_path: None, amplicon_folder_path: None
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# mozaiko INFO: MultiBarcodeTools file created to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode/multibarcode_input.tsv
# mozaiko INFO: MultiBarcodePipeline completed. Output in /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode
# mozaiko INFO: Primer Ranking results saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Ireland_ranked_primers.tsv.
# mozaiko INFO: Intermediate ranks saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Ireland_ranked_primers_intermediate_ranks.tsv.
# /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Czech_ranked_primers.tsv
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# results_folder: /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks, insert_folder_path: None, amplicon_folder_path: None
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# mozaiko INFO: MultiBarcodeTools file created to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode/multibarcode_input.tsv
# mozaiko INFO: MultiBarcodePipeline completed. Output in /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode
# mozaiko INFO: Primer Ranking results saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Czech_ranked_primers.tsv.
# mozaiko INFO: Intermediate ranks saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Czech_ranked_primers_intermediate_ranks.tsv.
# /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Finland_ranked_primers.tsv
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# results_folder: /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks, insert_folder_path: None, amplicon_folder_path: None
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# mozaiko INFO: MultiBarcodeTools file created to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode/multibarcode_input.tsv
# mozaiko INFO: MultiBarcodePipeline completed. Output in /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode
# mozaiko INFO: Primer Ranking results saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Finland_ranked_primers.tsv.
# mozaiko INFO: Intermediate ranks saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Finland_ranked_primers_intermediate_ranks.tsv.
# /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/france_ranked_primers.tsv
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# results_folder: /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks, insert_folder_path: None, amplicon_folder_path: None
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# mozaiko INFO: MultiBarcodeTools file created to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode/multibarcode_input.tsv
# mozaiko INFO: MultiBarcodePipeline completed. Output in /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode
# mozaiko INFO: Primer Ranking results saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/france_ranked_primers.tsv.
# mozaiko INFO: Intermediate ranks saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/france_ranked_primers_intermediate_ranks.tsv.
# /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/poland_ranked_primers.tsv
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# results_folder: /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks, insert_folder_path: None, amplicon_folder_path: None
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# mozaiko INFO: MultiBarcodeTools file created to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode/multibarcode_input.tsv
# mozaiko INFO: MultiBarcodePipeline completed. Output in /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode
# mozaiko INFO: Primer Ranking results saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/poland_ranked_primers.tsv.
# mozaiko INFO: Intermediate ranks saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/poland_ranked_primers_intermediate_ranks.tsv.
# /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Austria_ranked_primers.tsv
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# results_folder: /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks, insert_folder_path: None, amplicon_folder_path: None
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# mozaiko INFO: MultiBarcodeTools file created to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode/multibarcode_input.tsv
# mozaiko INFO: MultiBarcodePipeline completed. Output in /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode
# mozaiko INFO: Primer Ranking results saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Austria_ranked_primers.tsv.
# mozaiko INFO: Intermediate ranks saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Austria_ranked_primers_intermediate_ranks.tsv.
# /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Sweden_ranked_primers.tsv
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# results_folder: /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks, insert_folder_path: None, amplicon_folder_path: None
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# mozaiko INFO: MultiBarcodeTools file created to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode/multibarcode_input.tsv
# mozaiko INFO: MultiBarcodePipeline completed. Output in /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode
# mozaiko INFO: Primer Ranking results saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Sweden_ranked_primers.tsv.
# mozaiko INFO: Intermediate ranks saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Sweden_ranked_primers_intermediate_ranks.tsv.
# /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Portugal_ranked_primers.tsv
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# results_folder: /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks, insert_folder_path: None, amplicon_folder_path: None
# Set insert_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/filtered, amplicon_folder_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/amplicon/filtered and incomplete_pbs_path to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/incomplete_pbs/filtered/filtered_intersection.
# mozaiko INFO: MultiBarcodeTools file created to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode/multibarcode_input.tsv
# mozaiko INFO: MultiBarcodePipeline completed. Output in /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/insert/multibarcode
# mozaiko INFO: Primer Ranking results saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Portugal_ranked_primers.tsv.
# mozaiko INFO: Intermediate ranks saved to /home/camilababo/Documents/coding-projects/DNAquaIMG-tool/mozaico/data/output_data/diat-barcode-harmonized-test-ranks/Portugal_ranked_primers_intermediate_ranks.tsv.
